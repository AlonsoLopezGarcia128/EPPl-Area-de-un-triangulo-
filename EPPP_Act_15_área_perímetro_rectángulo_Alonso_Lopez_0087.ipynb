# %% [markdown]
# <a href="https://colab.research.google.com/github/AlonsoLopezGarcia128/EPPl-Area-de-un-triangulo-/blob/main/EPPP_Act_15_%C3%A1rea_per%C3%ADmetro_rect%C3%A1ngulo_Alonso_Lopez_0087.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Alonso Lopez NL = 31
#
# #### 📝 Redacción del Problema
# #### Se requiere desarrollar un programa interactivo en Python que permita a un usuario calcular propiedades geométricas básicas de un rectángulo. El programa debe mostrar un menú persistente que permita calcular el área o el perímetro basándose en la base y la altura proporcionadas por el usuario, repitiéndose hasta que el usuario decida salir.
# ### 📐 Fórmulas a UtilizarPara un rectángulo con base ($b$) y altura ($h$), las fórmulas son:
# 1. Área: $A = b \times h$
# 2. Perímetro: $P = 2 \times (b + h)$
# ![texto del vínculo](https://raw.githubusercontent.com/AlonsoLopezGarcia128/EPPP-Act-15-area-perimetro-rectangulo-Alonso-Lopez/refs/heads/main/Area-del-Rectangulo.jpg)

# %%
# ---------------------------------------------------------
# PROGRAMA: Calculadora de Rectángulos Interactiva
# ---------------------------------------------------------

def calcular_area():
    print("\n--- Cálculo de Área ---")
    base = float(input("Introduce la base del rectángulo: "))
    altura = float(input("Introduce la altura del rectángulo: "))
    area = base * altura
    print(f"✅ El área del rectángulo es: {area}")

def calcular_perimetro():
    print("\n--- Cálculo de Perímetro ---")
    base = float(input("Introduce la base del rectángulo: "))
    altura = float(input("Introduce la altura del rectángulo: "))
    perimetro = 2 * (base + altura)
    print(f"✅ El perímetro del rectángulo es: {perimetro}")

def menu():
    continuar = True

    while continuar:
        print("\n" + "="*30)
        print("     MENÚ DE GEOMETRÍA")
        print("="*30)
        print("1. Calcular Área del Rectángulo")
        print("2. Calcular Perímetro del Rectángulo")
        print("3. Salir")
        print("="*30)

        opcion = input("Selecciona una opción (1-3): ")

        if opcion == "1":
            calcular_area()
        elif opcion == "2":
            calcular_perimetro()
        elif opcion == "3":
            print("\n¡Gracias por usar el programa! Hasta pronto. 👋")
            continuar = False
        else:
            print("\n❌ Opción no válida. Por favor, intenta de nuevo.")

# Llamada principal para iniciar el programa
if __name__ == "__main__":
    menu()


print("Programa realizado por Alonso Lopez garcia NL = 31")
# Out:
# ...
#      MENÚ DE GEOMETRÍA
# ...
# 1. Calcular Área del Rectángulo
# 2. Calcular Perímetro del Rectángulo
# 3. Salir
# ...
# Selecciona una opción (1-3): 1
#
# --- Cálculo de Área ---
# Introduce la base del rectángulo: 4
# Introduce la altura del rectángulo: 2
# ✅ El área del rectángulo es: 8.0
#
# ...
#      MENÚ DE GEOMETRÍA
# ...
# 1. Calcular Área del Rectángulo
# 2. Calcular Perímetro del Rectángulo
# 3. Salir
# ...
# Selecciona una opción (1-3): 2
#
# --- Cálculo de Perímetro ---
# Introduce la base del rectángulo: 4
# Introduce la altura del rectángulo: 2
# ✅ El perímetro del rectángulo es: 12.0
#
# ...
#      MENÚ DE GEOMETRÍA
# ...
# 1. Calcular Área del Rectángulo
# 2. Calcular Perímetro del Rectángulo
# 3. Salir
# ...
# Selecciona una opción (1-3): 3
#
# ¡Gracias por usar el programa! Hasta pronto. 👋
# Programa realizado por Alonso Lopez garcia NL = 31

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/AlonsoLopezGarcia128/EPPP-Act-15-area-perimetro-rectangulo-Alonso-Lopez/refs/heads/main/area%20perimetro%20rectangulo%20Python.png)
